# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display the map
display(m)
display(main_icon)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Marker(icon=AwesomeIcon(marker_color='red', name='circle'), location=[21.3445, -157.9746], options=['alt', 'dr…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display the map and main icon
display(m)
display(main_icon)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Marker(icon=AwesomeIcon(marker_color='red', name='circle'), location=[21.3445, -157.9746], options=['alt', 'dr…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for finalizing ship location
def finalize_ship_location(button):
    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Add event handler to finalize button
finalize_button.on_click(finalize_ship_location)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:766, in Widget._handle_msg(self, msg)
#     764         if 'buffer_paths' in data:
#     765             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 766         self.set_state(state)
#     768 # Handle a state request.
#     769 elif method == 'request_state':
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:648, in Widget.set_state(self, sync_data)
#     645 if name in self.keys:
#     646     from_json = self.trait_metadata(name, 'from_json',
#     647                                     self._trait_from_json)
# --> 648     self.set_trait(name, from_json(sync_data[name], self))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\traitlets\traitlets.py:1738, in HasTraits.set_trait(self, name, value)
#    1736     raise TraitError(f"Class {cls.__name__} does not have a trait named {name}")
#    1737 else:
# -> 1738     getattr(cls, name).set(self, value)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\traitlets\traitlets.py:703, in TraitType.set(self, obj, value)
#     702 def set(self, obj, value):
# --> 703     new_value = self._validate(obj, value)
#     704     try:
#     705         old_value = obj._trait_values[self.name]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\traitlets\traitlets.py:735, in TraitType._validate(self, obj, value)
#     733     return value
#     734 if hasattr(self, "validate"):
# --> 735     value = self.validate(obj, value)
#     736 if obj._cross_validation_lock is False:
#     737     value = self._cross_validate(obj, value)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\traitlets\traitlets.py:2417, in Float.validate(self, obj, value)
#    2415     value = float(value)
#    2416 if not isinstance(value, float):
# -> 2417     self.error(obj, value)
#    2418 return _validate_bounds(self, obj, value)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\traitlets\traitlets.py:841, in TraitType.error(self, obj, value, error, info)
#     835 else:
#     836     e = "The '{}' trait expected {}, not {}.".format(
#     837         self.name,
#     838         self.info(),
#     839         describe("the", value),
#     840     )
# --> 841 raise TraitError(e)
#
# TraitError: The 'east' trait of a Map instance expected a float, not the NoneType None.

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for finalizing ship location
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = initial_location
    for _ in range(100):
        random_location = [
            initial_location[0] + np.random.uniform(-0.0005, 0.0005),
            initial_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Add event handler to finalize button
finalize_button.on_click(finalize_ship_location)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Event handler for main icon drag and drop
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Bind event handler to main icon
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for finalizing ship location
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Add event handler to finalize button
finalize_button.on_click(finalize_ship_location)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display
from geopy.geocoders import Nominatim

# Initialize geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

# Function to get coordinates from location name
def get_coordinates(location_name):
    location = geolocator.geocode(location_name)
    if location:
        return [location.latitude, location.longitude]
    else:
        return None

# Prompt user to enter a location
location_input = widgets.Text(
    value='Pearl Harbor',
    placeholder='Enter a location',
    description='Location:',
    disabled=False
)
display(location_input)

# Create the main map
initial_location_name = location_input.value
initial_location = get_coordinates(initial_location_name)
if initial_location:
    m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))
    main_icon = Marker(
        location=initial_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
    )
    m.add_layer(main_icon)
    display(m)
else:
    print("Location not found.")

# Rest of the code remains the same...
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 5
#       3 from ipyleaflet import Map, Marker, AwesomeIcon
#       4 from IPython.display import display
# ----> 5 from geopy.geocoders import Nominatim
#       7 # Initialize geocoder
#       8 geolocator = Nominatim(user_agent="geoapiExercises")
#
# ModuleNotFoundError: No module named 'geopy'

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display
from geopy.geocoders import Nominatim

# Initialize geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

# Function to get coordinates from location name
def get_coordinates(location_name):
    location = geolocator.geocode(location_name)
    if location:
        return [location.latitude, location.longitude]
    else:
        return None

# Prompt user to enter a location
location_input = widgets.Text(
    value='Pearl Harbor',
    placeholder='Enter a location',
    description='Location:',
    disabled=False
)
display(location_input)

# Create the main map
initial_location_name = location_input.value
initial_location = get_coordinates(initial_location_name)
if initial_location:
    m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))
    main_icon = Marker(
        location=initial_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
    )
    m.add_layer(main_icon)
    display(m)
else:
    print("Location not found.")

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for finalizing ship location
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Add event handler to finalize button
finalize_button.on_click(finalize_ship_location)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 5
#       3 from ipyleaflet import Map, Marker, AwesomeIcon
#       4 from IPython.display import display
# ----> 5 from geopy.geocoders import Nominatim
#       7 # Initialize geocoder
#       8 geolocator = Nominatim(user_agent="geoapiExercises")
#
# ModuleNotFoundError: No module named 'geopy'

# %%
pip install geopy
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      -------------------------------------- 40.3/40.3 kB 970.5 kB/s eta 0:00:00
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------------------------- 125.4/125.4 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display
from geopy.geocoders import Nominatim

# Initialize geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

# Function to get coordinates from location name
def get_coordinates(location_name):
    location = geolocator.geocode(location_name)
    if location:
        return [location.latitude, location.longitude]
    else:
        return None

# Prompt user to enter a location
location_input = widgets.Text(
    value='Pearl Harbor',
    placeholder='Enter a location',
    description='Location:',
    disabled=False
)
display(location_input)

# Create the main map
initial_location_name = location_input.value
initial_location = get_coordinates(initial_location_name)
if initial_location:
    m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))
    main_icon = Marker(
        location=initial_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
    )
    m.add_layer(main_icon)
    display(m)
else:
    print("Location not found.")

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for finalizing ship location
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Add event handler to finalize button
finalize_button.on_click(finalize_ship_location)

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display
from geopy.geocoders import Nominatim

# Initialize geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

# Function to get coordinates from location name
def get_coordinates(location_name):
    location = geolocator.geocode(location_name)
    if location:
        return [location.latitude, location.longitude]
    else:
        return None

# Create the main map with a default location
initial_location_name = "Pearl Harbor"
initial_location = get_coordinates(initial_location_name)
m = Map(center=initial_location, zoom=10, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)
display(clear_button)

# Function to finalize ship location
def finalize_ship_location(button):
    main_icon_location = main_icon.location

    # Move main icon to average position of 100 random movements within 50 yards of the original position
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Finalize button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)

# Display finalize button
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Add main icon to the map
m.add_layer(main_icon)

# Display the map
display(m)
# Out:
# ---------------------------------------------------------------------------
# AdapterHTTPError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopy\adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopy\adapters.py:500, in RequestsAdapter._request(self, url, timeout, headers)
#     499     if resp.status_code >= 400:
# --> 500         raise AdapterHTTPError(
#     501             "Non-successful status code %s" % resp.status_code,
#     502             status_code=resp.status_code,
#     503             headers=resp.headers,
#     504             text=resp.text,
#     505         )
#     507 return resp
#
# AdapterHTTPError: Non-successful status code 403
#
# The above exception was the direct cause of the following exception:
#
# GeocoderInsufficientPrivileges            Traceback (most recent call last)
# Cell In[13], line 20
#      18 # Create the main map with a default location
#      19 initial_location_name = "Pearl Harbor"
# ---> 20 initial_location = get_coordinates(initial_location_name)
#      21 m = Map(center=initial_location, zoom=10, layout=dict(height='600px'))
#      23 # Main icon
#
# Cell In[13], line 12, in get_coordinates(location_name)
#      11 def get_coordinates(location_name):
# ---> 12     location = geolocator.geocode(location_name)
#      13     if location:
#      14         return [location.latitude, location.longitude]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopy\geocoders\base.py:388, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     386         return callback(result)
#     387 except Exception as error:
# --> 388     res = self._adapter_error_handler(error)
#     389     if res is NONE_RESULT:
#     390         return None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geopy\geocoders\base.py:411, in Geocoder._adapter_error_handler(self, error)
#     407         raise exc_cls(
#     408             str(error), retry_after=get_retry_after(error.headers)
#     409         ) from error
#     410     else:
# --> 411         raise exc_cls(str(error)) from error
#     412 else:
#     413     res = self._geocoder_exception_handler(error)
#
# GeocoderInsufficientPrivileges: Non-successful status code 403

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Event handler for main icon drag and drop
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Bind event handler to main icon
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for finalizing ship location
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Add event handler to finalize button
finalize_button.on_click(finalize_ship_location)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Set initial location to Pearl Harbor
initial_location = [21.3445, -157.9746]  # Coordinates for Pearl Harbor

# Create the main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons
secondary_icons = []

# Dictionary to store ship types for each secondary icon
secondary_ship_types = {}

def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    random_location = [
        initial_location[0] + np.random.uniform(-0.01, 0.01),
        initial_location[1] + np.random.uniform(-0.01, 0.01)
    ]

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)
display(clear_button)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for finalizing ship location
def finalize_ship_location(button):
    main_icon_location = main_icon.location

    # Move main icon to average position of 100 random movements within 50 yards of the original position
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Add event handler to finalize button
finalize_button.on_click(finalize_ship_location)
# Out:
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Define initial location for Pearl Harbor
initial_location = [21.3445, -157.9746]

# Create main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Add clear button to remove all ships
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)
display(clear_button)
# Out:
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Button(description='Clear Ships', style=ButtonStyle())

# %%
import ipywidgets as widgets
from ipyleaflet import Map

# Define the coordinates for the maps
coordinates = {
    "Pearl Harbor": [21.3445, -157.9746],
    "Norfolk Naval Station, Virginia": [36.9377, -76.3195],
    "Middle of the Atlantic Ocean": [27.4073, -40.3018],
    "Near Japan": [27.3930, 166.5527]  # Adjusted coordinates near Japan
}

# Create maps centered on the specified coordinates
maps = {name: Map(center=coord, zoom=10) for name, coord in coordinates.items()}

# Create a dropdown widget to select the map
map_dropdown = widgets.Dropdown(
    options=list(coordinates.keys()),
    description='Select a Map:',
    disabled=False,
)

# Display the dropdown widget
display(map_dropdown)
# Out:
# Dropdown(description='Select a Map:', options=('Pearl Harbor', 'Norfolk Naval Station, Virginia', 'Middle of t…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Define initial location for Pearl Harbor
initial_location = [21.3445, -157.9746]

# Create main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Display main icon on the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier')

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser')

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer')

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship')

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Add clear button to remove all ships
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)
display(clear_button)

# Add finalize map selection button
def finalize_map_selection(button):
    selected_map = map_selection_widget.value
    if selected_map == "Pearl Harbor":
        initial_location = [21.3445, -157.9746]
    elif selected_map == "Norfolk Naval Station Virginia":
        initial_location = [36.9485, -76.3089]
    elif selected_map == "Middle of the Atlantic Ocean":
        initial_location = [27.3906, -40.3018]
    elif selected_map == "27°23'34.9\"N 166°33'09.7\"E":
        initial_location = [27.3927, 166.5527]

    # Update map center
    m.center = initial_location
    main_icon.location = initial_location

finalize_map_selection_button = widgets.Button(description="Finalize Map Selection")
finalize_map_selection_button.on_click(finalize_map_selection)

# Map selection dropdown
map_options = ["Pearl Harbor", "Norfolk Naval Station Virginia", "Middle of the Atlantic Ocean", "27°23'34.9\"N 166°33'09.7\"E"]
map_selection_widget = widgets.Dropdown(options=map_options, description="Select Map")

# Display map selection widget and finalize button
display(map_selection_widget, finalize_map_selection_button)
# Out:
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Button(description='Clear Ships', style=ButtonStyle())
# Dropdown(description='Select Map', options=('Pearl Harbor', 'Norfolk Naval Station Virginia', 'Middle of the A…
# Button(description='Finalize Map Selection', style=ButtonStyle())

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Define initial location for Pearl Harbor
initial_location = [21.3445, -157.9746]

# Create main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Add clear button to remove all ships
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)
display(clear_button)

# Map selection dropdown
map_options = ["Pearl Harbor", "Norfolk Naval Station Virginia", "Middle of the Atlantic Ocean", "Middle of the Pacific Ocean"]
map_selection_widget = widgets.Dropdown(options=map_options, description="Select Map")

# Add finalize map selection button
def finalize_map_selection(button):
    selected_map = map_selection_widget.value
    if selected_map == "Pearl Harbor":
        initial_location = [21.3445, -157.9746]
    elif selected_map == "Norfolk Naval Station Virginia":
        initial_location = [36.9485, -76.3089]
    elif selected_map == "Middle of the Atlantic Ocean":
        initial_location = [27.3906, -40.3018]
    elif selected_map == "Middle of the Pacific Ocean":
        initial_location = [27.3927, 166.5527]

    # Update map center
    m.center = initial_location
    main_icon.location = initial_location

    # Update ship placement initial location
    for icon in secondary_icons:
        icon.location = initial_location

# Add event handler to finalize map selection button
finalize_map_selection_button = widgets.Button(description="Finalize Map Selection")
finalize_map_selection_button.on_click(finalize_map_selection)

# Display map selection widget and finalize button
display(map_selection_widget, finalize_map_selection_button)
# Out:
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Button(description='Clear Ships', style=ButtonStyle())
# Dropdown(description='Select Map', options=('Pearl Harbor', 'Norfolk Naval Station Virginia', 'Middle of the A…
# Button(description='Finalize Map Selection', style=ButtonStyle())

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map selection
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Define initial location for Pearl Harbor
initial_location = [21.3445, -157.9746]

# Create main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Map selection dropdown
map_options = ["Pearl Harbor", "Norfolk Naval Station Virginia", "Middle of the Atlantic Ocean", "27°23'34.9\"N 166°33'09.7\"E"]
map_selection_widget = widgets.Dropdown(options=map_options, description="Select Map")

# Add finalize map selection button
def finalize_map_selection(button):
    selected_map = map_selection_widget.value
    if selected_map == "Pearl Harbor":
        initial_location = [21.3445, -157.9746]
    elif selected_map == "Norfolk Naval Station Virginia":
        initial_location = [36.9485, -76.3089]
    elif selected_map == "Middle of the Atlantic Ocean":
        initial_location = [27.4074, -40.3018]
    elif selected_map == "27°23'34.9\"N 166°33'09.7\"E":
        initial_location = [27.392917, 166.5527]

    # Update map center
    m.center = initial_location
    main_icon.location = initial_location

    # Clear placed ships
    clear_ships()

# Add event handler to finalize map selection button
finalize_map_selection_button = widgets.Button(description="Finalize Map Selection")
finalize_map_selection_button.on_click(finalize_map_selection)

# Display map selection widget and finalize button
display(map_selection_widget, finalize_map_selection_button)
# Out:
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Dropdown(description='Select Map', options=('Pearl Harbor', 'Norfolk Naval Station Virginia', 'Middle of the A…
# Button(description='Finalize Map Selection', style=ButtonStyle())

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map selection
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Define initial location for Pearl Harbor
initial_location = [21.3445, -157.9746]

# Create main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Add main icon to the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)
# Out:
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map change
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Define initial location for Pearl Harbor
initial_location = [21.3445, -157.9746]

# Create main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Add main icon to the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)
# Out:
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map change
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Define initial location for Pearl Harbor
initial_location = [21.3445, -157.9746]

# Create main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Add main icon to the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)
# Out:
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map change
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Define initial location for Pearl Harbor
initial_location = [21.3445, -157.9746]

# Create main map
m = Map(center=initial_location, zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_location,
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Add main icon to the map
m.add_layer(main_icon)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)
# Out:
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map change
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Define initial locations for different maps
initial_locations = {
    "Pearl Harbor": [21.3445, -157.9746],
    "Norfolk Naval Station, Virginia": [36.9375, -76.3186],
    "Middle of the Atlantic Ocean": [27.4076, -40.3018],
    "Middle of the Pacific Ocean": [27.3897, 166.5527]
}

# Create map selection dropdown widget
map_selection_dropdown = widgets.Dropdown(
    options=list(initial_locations.keys()),
    description='Select Map:',
    disabled=False
)

# Create main map
m = Map(center=initial_locations[map_selection_dropdown.value], zoom=6, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_locations[map_selection_dropdown.value],
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Event handler for map selection change
def on_map_selection_change(change):
    m.center = initial_locations[change['new']]
    clear_ships()
    main_icon.location = initial_locations[change['new']]

# Bind event handler to map selection dropdown
map_selection_dropdown.observe(on_map_selection_change, names='value')

# Add main icon to the map
m.add_layer(main_icon)

# Display the map selection dropdown
display(map_selection_dropdown)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier (blue)")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser (green)")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer (black)")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship (white)")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)

# Add clear button to remove all ships
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)
display(clear_button)
# Out:
# Dropdown(description='Select Map:', options=('Pearl Harbor', 'Norfolk Naval Station, Virginia', 'Middle of the…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier (blue)', style=ButtonStyle()), Button(description='Add Cruiser …
# Button(description='Clear Ships', style=ButtonStyle())
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: clear_ships() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: clear_ships() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: clear_ships() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: clear_ships() takes 0 positional arguments but 1 was given
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: clear_ships() takes 0 positional arguments but 1 was given

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map change
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Define initial locations for different maps
initial_locations = {
    "Pearl Harbor": [21.3445, -157.9746],
    "Norfolk Naval Station, Virginia": [36.9375, -76.3186],
    "Middle of the Atlantic Ocean": [27.4076, -40.3018],
    "Middle of the Pacific Ocean": [27.3897, 166.5527]
}

# Create map selection dropdown widget
map_selection_dropdown = widgets.Dropdown(
    options=list(initial_locations.keys()),
    description='Select Map:',
    disabled=False
)

# Create main map
m = Map(center=initial_locations[map_selection_dropdown.value], zoom=6, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_locations[map_selection_dropdown.value],
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Event handler for map selection change
def on_map_selection_change(change):
    m.center = initial_locations[change['new']]
    clear_ships()
    main_icon.location = initial_locations[change['new']]

# Bind event handler to map selection dropdown
map_selection_dropdown.observe(on_map_selection_change, names='value')

# Add main icon to the map
m.add_layer(main_icon)

# Display the map selection dropdown
display(map_selection_dropdown)

# Display the map
display(m)

# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)
# Out:
# Dropdown(description='Select Map:', options=('Pearl Harbor', 'Norfolk Naval Station, Virginia', 'Middle of the…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            initial_location[0] + np.random.uniform(-0.01, 0.01),
            initial_location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map change
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Function to handle map selection change
def on_map_selection_change(change):
    m.center = initial_locations[change['new']]
    clear_ships()
    main_icon.location = initial_locations[change['new']]

# Function to handle "Confirm Yield" button click
def confirm_yield(button):
    global weapon_yield
    weapon_yield = float(yield_input.value)

# Define initial locations for different maps
initial_locations = {
    "Pearl Harbor": [21.3445, -157.9746],
    "Norfolk Naval Station, Virginia": [36.9375, -76.3186],
    "Middle of the Atlantic Ocean": [27.4076, -40.3018],
    "Middle of the Pacific Ocean": [27.3897, 166.5527]
}

# Create map selection dropdown widget
map_selection_dropdown = widgets.Dropdown(
    options=list(initial_locations.keys()),
    description='Select Map:',
    disabled=False
)

# Create "Weapon Yield" input field
yield_input = widgets.FloatText(
    value=1.0,
    description='Weapon Yield:',
    disabled=False
)

# Create "Confirm Yield" button
confirm_yield_button = widgets.Button(
    description='Confirm Yield',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Confirm Weapon Yield',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)

# Create main map
m = Map(center=initial_locations[map_selection_dropdown.value], zoom=6, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_locations[map_selection_dropdown.value],
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Event handler for map selection change
map_selection_dropdown.observe(on_map_selection_change, names='value')

# Event handler for "Confirm Yield" button click
confirm_yield_button.on_click(confirm_yield)

# Add main icon to the map
m.add_layer(main_icon)

# Display the widgets
display(map_selection_dropdown)
display(yield_input)
display(confirm_yield_button)
display(m)
# Out:
# Dropdown(description='Select Map:', options=('Pearl Harbor', 'Norfolk Naval Station, Virginia', 'Middle of the…
# FloatText(value=1.0, description='Weapon Yield:')
# Button(description='Confirm Yield', icon='check', style=ButtonStyle(), tooltip='Confirm Weapon Yield')
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %%
import numpy as np
import ipywidgets as widgets
from ipyleaflet import Map, Marker, AwesomeIcon
from IPython.display import display

# Function to calculate distance between two coordinates
def calculate_distance(coord1, coord2):
    x1, y1 = coord1
    x2, y2 = coord2
    distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2) * 111320 / 0.9144  # Conversion from degrees to yards
    return distance

# Function to add a new ship icon
def add_ship(ship_color, ship_type, initial_location):
    while True:
        # Generate random location within the map boundaries
        random_location = [
            main_icon.location[0] + np.random.uniform(-0.01, 0.01),
            main_icon.location[1] + np.random.uniform(-0.01, 0.01)
        ]

        # Check distance from existing icons
        too_close = False
        for icon in secondary_icons:
            distance = calculate_distance(icon.location, random_location)
            if distance < 100:
                too_close = True
                break

        if not too_close:
            break

    new_icon = Marker(
        location=random_location,
        draggable=True,
        icon=AwesomeIcon(name='circle', marker_color=ship_color, icon_color='white')
    )
    secondary_icons.append(new_icon)
    secondary_ship_types[new_icon] = ship_type
    m.add_layer(new_icon)

# Function to remove all ships from the map
def clear_ships():
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Function to handle main icon movement
def on_main_icon_move(event, main_icon):
    main_icon.location = event['new']

# Function to finalize ship location and calculate distances
def finalize_ship_location(button):
    # Move main icon to average position of 100 random movements within 50 yards of the original position
    main_icon_location = main_icon.location
    for _ in range(100):
        random_location = [
            main_icon_location[0] + np.random.uniform(-0.0005, 0.0005),
            main_icon_location[1] + np.random.uniform(-0.0005, 0.0005)
        ]
        distance = calculate_distance(main_icon_location, random_location)
        if distance <= 50:
            main_icon_location = random_location

    main_icon.location = main_icon_location

    # Calculate distances from main icon to all secondary icons
    distances = []
    for icon in secondary_icons:
        distance = calculate_distance(main_icon.location, icon.location)
        distances.append((secondary_ship_types[icon], distance))

    # Display distances in the text widget
    distances_text.value = "\n".join(f"{ship}: {distance:.2f} yards" for ship, distance in distances)

# Function to handle map change
def on_map_change(change):
    if change['name'] == 'center':
        clear_ships()
        main_icon.location = change['new']

# Function to handle "Confirm Yield" button click
def confirm_yield(button):
    global weapon_yield
    weapon_yield = float(yield_input.value)
        
# Define initial locations for different maps
initial_locations = {
    "Pearl Harbor": [21.3445, -157.9746],
    "Norfolk Naval Station, Virginia": [36.9375, -76.3186],
    "Middle of the Atlantic Ocean": [27.4076, -40.3018],
    "Middle of the Pacific Ocean": [27.3897, 166.5527]
}

# Create map selection dropdown widget
map_selection_dropdown = widgets.Dropdown(
    options=list(initial_locations.keys()),
    description='Select Map:',
    disabled=False
)

# Create "Weapon Yield" input field
yield_input = widgets.FloatText(
    value=1.0,
    description='Weapon Yield:',
    disabled=False
)

# Create "Confirm Yield" button
confirm_yield_button = widgets.Button(
    description='Confirm Yield',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Confirm Weapon Yield',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)

# Create main map
m = Map(center=initial_locations[map_selection_dropdown.value], zoom=15, layout=dict(height='600px'))

# Main icon
main_icon = Marker(
    location=initial_locations[map_selection_dropdown.value],
    draggable=True,
    icon=AwesomeIcon(name='circle', marker_color='red', icon_color='white')
)

# Initialize secondary icons list and ship types dictionary
secondary_icons = []
secondary_ship_types = {}

# Event handler for main icon movement
main_icon.observe(lambda event: on_main_icon_move(event, main_icon), names='location')

# Event handler for map change
m.observe(on_map_change)

# Event handler for map selection change
def on_map_selection_change(change):
    m.center = initial_locations[change['new']]
    clear_ships()
    main_icon.location = initial_locations[change['new']]

# Bind event handler to map selection dropdown
map_selection_dropdown.observe(on_map_selection_change, names='value')

# Add main icon to the map
m.add_layer(main_icon)

# Event handler for "Confirm Yield" button click
confirm_yield_button.on_click(confirm_yield)

display(yield_input)
display(confirm_yield_button)

# Display the map selection dropdown
display(map_selection_dropdown)

# Display the map
display(m)

# Event handler to add a carrier icon
def add_carrier(button):
    add_ship('blue', 'Carrier', m.center)

# Event handler to add a cruiser icon
def add_cruiser(button):
    add_ship('green', 'Cruiser', m.center)

# Event handler to add a destroyer icon
def add_destroyer(button):
    add_ship('black', 'Destroyer', m.center)

# Event handler to add a supply ship icon
def add_supply_ship(button):
    add_ship('white', 'Supply Ship', m.center)
    
def clear_ships(button):
    for icon in secondary_icons:
        m.remove_layer(icon)
    secondary_icons.clear()

# Add clear button
clear_button = widgets.Button(description="Clear Ships")
clear_button.on_click(clear_ships)

# Add clear button to the display
display(clear_button)

# Add secondary icon buttons
add_carrier_button = widgets.Button(description="Add Carrier")
add_carrier_button.on_click(add_carrier)
add_cruiser_button = widgets.Button(description="Add Cruiser")
add_cruiser_button.on_click(add_cruiser)
add_destroyer_button = widgets.Button(description="Add Destroyer")
add_destroyer_button.on_click(add_destroyer)
add_supply_ship_button = widgets.Button(description="Add Supply Ship")
add_supply_ship_button.on_click(add_supply_ship)

# Display buttons
ship_buttons = widgets.HBox([add_carrier_button, add_cruiser_button, add_destroyer_button, add_supply_ship_button])
display(ship_buttons)
# Display finalize ship location button
finalize_button = widgets.Button(description="Finalize Ship Location")
finalize_button.on_click(finalize_ship_location)
display(finalize_button)

# Text widget to display distances
distances_text = widgets.Textarea(layout={'height': '100px', 'width': '400px'})
display(distances_text)
# Out:
# FloatText(value=1.0, description='Weapon Yield:')
# Button(description='Confirm Yield', icon='check', style=ButtonStyle(), tooltip='Confirm Weapon Yield')
# Dropdown(description='Select Map:', options=('Pearl Harbor', 'Norfolk Naval Station, Virginia', 'Middle of the…
# Map(center=[21.3445, -157.9746], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…
# Button(description='Clear Ships', style=ButtonStyle())
# HBox(children=(Button(description='Add Carrier', style=ButtonStyle()), Button(description='Add Cruiser', style…
# Button(description='Finalize Ship Location', style=ButtonStyle())
# Textarea(value='', layout=Layout(height='100px', width='400px'))
